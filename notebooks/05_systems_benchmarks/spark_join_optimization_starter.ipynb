# %% [markdown]
# # Spark Join Optimization Starter
#
# Use this notebook to reason about join strategy trade-offs (broadcast vs shuffle joins).

# %%
import pandas as pd

fact = pd.DataFrame({'id': [1, 2, 3, 4, 5], 'dim_id': [10, 11, 10, 12, 11], 'value': [100, 120, 110, 90, 130]})
dim_small = pd.DataFrame({'dim_id': [10, 11, 12], 'name': ['A', 'B', 'C']})

joined = fact.merge(dim_small, on='dim_id', how='left')
joined

# %% [markdown]
# ## Spark Thinking Checklist
#
# 1. If one side is tiny, prefer broadcast join.
# 2. If both sides are large, optimize partitioning before join.
# 3. Inspect skewed keys and apply salting if needed.
# 4. Validate query plan (`explain`) before and after optimization.

# %%
# Practice task:
# - Add a skewed key distribution and discuss expected Spark behavior.
# - Write pseudo-code for repartition + broadcast strategy.
print('Complete the practice tasks in markdown notes below this cell.')
